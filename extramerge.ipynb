# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import scipy.stats as st
from scipy import stats

# %%
path = "mergefinal.csv"
merge6 = pd.read_csv(path)
merge6.head()
merge6 = merge6[['LOCATION', 'Year', 'Education Value', 'GDP Value', 'LifeExp Value',
       'Population Value', 'PopulationDensityAsOf1July(PersonsPerSquareKm)', 'TotalFertilityRate(LiveBirthsPerWoman)','LifeExpectancyAtBirthBothSexes(years)', 'InfantMortalityRate(InfantDeathsPer1000LiveBirths)']]
merge6.head()
# Out:
#     LOCATION  Year  Education Value  GDP Value  LifeExp Value  \
# 0  Australia  1950              NaN        NaN            NaN
# 1  Australia  1951              NaN        NaN            NaN
# 2  Australia  1952              NaN        NaN            NaN
# 3  Australia  1953              NaN        NaN            NaN
# 4  Australia  1954              NaN        NaN            NaN
#
#    Population Value  PopulationDensityAsOf1July(PersonsPerSquareKm)  \
# 0         8178700.0                                             1.1
# 1         8421700.0                                             1.1
# 2         8636500.0                                             1.1
# 3         8815300.0                                             1.1
# 4         8986500.0                                             1.2
#
#    TotalFertilityRate(LiveBirthsPerWoman)  \
# 0                                    3.06
# 1                                    3.06
# 2                                    3.18
# ...

# %%
merge6.dtypes
# Out:
# LOCATION                                               object
# Year                                                    int64
# Education Value                                       float64
# GDP Value                                             float64
# LifeExp Value                                         float64
# Population Value                                      float64
# PopulationDensityAsOf1July(PersonsPerSquareKm)        float64
# TotalFertilityRate(LiveBirthsPerWoman)                float64
# LifeExpectancyAtBirthBothSexes(years)                 float64
# InfantMortalityRate(InfantDeathsPer1000LiveBirths)    float64
# dtype: object

# %%
# Read in every country's population from the marker above
path2 = "australia-population-2023-10-17.csv"   
path3 = "austria-population-2023-10-18.csv"
path4 = "belgium-population-2023-10-18.csv"
path5 = "canada-population-2023-10-17.csv"
path6 = "Czechia?"
path7 = "denmark-population-2023-10-18.csv"
path8 = "finland-population-2023-10-17.csv"
path9 = "france-population-2023-10-17.csv"
path10 = "germany-population-2023-10-18.csv"
path11 = "greece-population-2023-10-17.csv"
path12 = "hungary-population-2023-10-18.csv"
path13 = "iceland-population-2023-10-18.csv"
path14 = "ireland-population-2023-10-17.csv"
path15 = "italy-population-2023-10-17.csv"
path16 = "japan-population-2023-10-18.csv"
path17 = "south-korea-population-2023-10-17.csv"
path18 = "luxembourg-population-2023-10-18.csv"
path19 = "mexico-population-2023-10-17.csv"
path20 = "netherlands-population-2023-10-18.csv"
path21 = "new-zealand-population-2023-10-18.csv"
path22 = "norway-population-2023-10-17.csv"
path23 = "poland-population-2023-10-17.csv"
path24 = "portugal-population-2023-10-18.csv"
# path25 = "slovakia-population-2023-10-18.csv"
path26 = "spain-population-2023-10-18.csv"
path27 = "sweden-population-2023-10-18.csv"
path28 = "switzerland-population-2023-10-18.csv"
path29 = "turkey-population-2023-10-18.csv"
path30 = "united-kingdom-population-2023-10-18.csv"
path31 = "united-states-population-2023-10-17.csv"
path32 = "russia-population-2023-10-18.csv"
path33 = "china-population-2023-10-17.csv"
path34 = "india-population-2023-10-17.csv"
path35 = "brazil-population-2023-10-18.csv"
path36 = "chile-population-2023-10-18.csv"
path37 = "colombia-population-2023-10-18.csv"
path38 = "estonia-population-2023-10-18.csv"
path39 = "israel-population-2023-10-17.csv"
path41 = "slovenia-population-2023-10-18.csv"
path44 = "indonesia-population-2023-10-17.csv"
path45 = "south-africa-population-2023-10-18.csv"
path46 = "latvia-population-2023-10-18.csv"
path47 = "argentina-population-2023-10-18.csv"
path48 = "bulgaria-population-2023-10-18.csv"
path49 = "costa-rica-population-2023-10-18.csv"
path50 = "croatia-population-2023-10-18.csv"
path51 = "cyprus-population-2023-10-18.csv"
path52 = "lithuania-population-2023-10-18.csv"
path53 = "malta-population-2023-10-18.csv"
path54 = "romania-population-2023-10-18.csv"
path55 = "saudi-arabia-population-2023-10-18.csv"
path56 = "singapore-population-2023-10-17.csv"

# %%
australia = pd.read_csv(path2)
austria = pd.read_csv(path3, skiprows=15)
belgium = pd.read_csv(path4, skiprows=15)
canada = pd.read_csv(path5, skiprows=15)
denmark = pd.read_csv(path7, skiprows=15)
finland = pd.read_csv(path8, skiprows=15)
france = pd.read_csv(path9, skiprows=15)
germany = pd.read_csv(path10, skiprows=15)
greece = pd.read_csv(path11, skiprows=15)
hungary = pd.read_csv(path12, skiprows=15)
iceland = pd.read_csv(path13, skiprows=15)
ireland = pd.read_csv(path14, skiprows=15)
italy = pd.read_csv(path15, skiprows=15)
japan = pd.read_csv(path16, skiprows=15)
south_korea = pd.read_csv(path17, skiprows=15)
luxembourg = pd.read_csv(path18, skiprows=15)
mexico = pd.read_csv(path19, skiprows=15)
netherlands = pd.read_csv(path20, skiprows=15)
new_zealand = pd.read_csv(path21, skiprows=15)
norway = pd.read_csv(path22, skiprows=15)
poland = pd.read_csv(path23, skiprows=15)
portugal = pd.read_csv(path24, skiprows=15)
# slovakia = pd.read_csv(path25, skiprows=15)
spain = pd.read_csv(path26, skiprows=15)
sweden = pd.read_csv(path27, skiprows=15)
switzerland = pd.read_csv(path28, skiprows=15)
turkey = pd.read_csv(path29, skiprows=15)
united_kingdom = pd.read_csv(path30, skiprows=15)
united_states = pd.read_csv(path31, skiprows=15)
russia = pd.read_csv(path32, skiprows=15)
china = pd.read_csv(path33, skiprows=15)
india = pd.read_csv(path34, skiprows=15)
brazil = pd.read_csv(path35, skiprows=15)
chile = pd.read_csv(path36, skiprows=15)
colombia = pd.read_csv(path37, skiprows=15)
estonia = pd.read_csv(path38, skiprows=15)
israel = pd.read_csv(path39, skiprows=15)
# lithuania = pd.read_csv(path40, skiprows=15)
slovenia = pd.read_csv(path41, skiprows=15)
# malaysia = pd.read_csv(path42, skiprows=15)
# thailand = pd.read_csv(path43, skiprows=15)
indonesia = pd.read_csv(path44, skiprows=15)
south_africa = pd.read_csv(path45, skiprows=15)
latvia = pd.read_csv(path46, skiprows=15)
argentina = pd.read_csv(path47, skiprows=15)
bulgaria = pd.read_csv(path48, skiprows=15)
costa_rica = pd.read_csv(path49, skiprows=15)
croatia = pd.read_csv(path50, skiprows=15)
cyprus = pd.read_csv(path51, skiprows=15)
lithuania = pd.read_csv(path52, skiprows=15)
malta = pd.read_csv(path53, skiprows=15)
romania = pd.read_csv(path54, skiprows=15)
saudi_arabia = pd.read_csv(path55, skiprows=15)
singapore = pd.read_csv(path56, skiprows=15)

# %%
# Change the data column to year and give only year value for each country
austria = austria.rename(columns={"date": "Year"})
australia = australia.rename(columns={"date": "Year"})
belgium = belgium.rename(columns={"date": "Year"})
canada = canada.rename(columns={"date": "Year"})
denmark = denmark.rename(columns={"date": "Year"})
finland = finland.rename(columns={"date": "Year"})
france = france.rename(columns={"date": "Year"})
germany = germany.rename(columns={"date": "Year"})
greece = greece.rename(columns={"date": "Year"})
hungary = hungary.rename(columns={"date": "Year"})
iceland = iceland.rename(columns={"date": "Year"})
ireland = ireland.rename(columns={"date": "Year"})
italy = italy.rename(columns={"date": "Year"})
japan = japan.rename(columns={"date": "Year"})
south_korea = south_korea.rename(columns={"date": "Year"})
luxembourg = luxembourg.rename(columns={"date": "Year"})
mexico = mexico.rename(columns={"date": "Year"})
netherlands = netherlands.rename(columns={"date": "Year"})
new_zealand = new_zealand.rename(columns={"date": "Year"})
norway = norway.rename(columns={"date": "Year"})
poland = poland.rename(columns={"date": "Year"})
portugal = portugal.rename(columns={"date": "Year"})
# slovakia = slovakia.rename(columns={"date": "Year"})
spain = spain.rename(columns={"date": "Year"})
sweden = sweden.rename(columns={"date": "Year"})
switzerland = switzerland.rename(columns={"date": "Year"})
turkey = turkey.rename(columns={"date": "Year"})
united_kingdom = united_kingdom.rename(columns={"date": "Year"})
united_states = united_states.rename(columns={"date": "Year"})
russia = russia.rename(columns={"date": "Year"})
china = china.rename(columns={"date": "Year"})
india = india.rename(columns={"date": "Year"})
brazil = brazil.rename(columns={"date": "Year"})
chile = chile.rename(columns={"date": "Year"})
colombia = colombia.rename(columns={"date": "Year"})
estonia = estonia.rename(columns={"date": "Year"})
israel = israel.rename(columns={"date": "Year"})
# lithuania = lithuania.rename(columns={"date": "Year"})
slovenia = slovenia.rename(columns={"date": "Year"})
# malaysia = malaysia.rename(columns={"date": "Year"})
# thailand = thailand.rename(columns={"date": "Year"})
indonesia = indonesia.rename(columns={"date": "Year"})
south_africa = south_africa.rename(columns={"date": "Year"})
latvia = latvia.rename(columns={"date": "Year"})
argentina = argentina.rename(columns={"date": "Year"})
bulgaria = bulgaria.rename(columns={"date": "Year"})
costa_rica = costa_rica.rename(columns={"date": "Year"})
croatia = croatia.rename(columns={"date": "Year"})
cyprus = cyprus.rename(columns={"date": "Year"})
lithuania = lithuania.rename(columns={"date": "Year"})
malta = malta.rename(columns={"date": "Year"})
romania = romania.rename(columns={"date": "Year"})
saudi_arabia = saudi_arabia.rename(columns={"date": "Year"})
singapore = singapore.rename(columns={"date": "Year"})

# %%
# Converted the year column to datetime and do it for every country
australia['Year'] = pd.to_datetime(australia['Year']).dt.year
austria['Year'] = pd.to_datetime(austria['Year']).dt.year
belgium['Year'] = pd.to_datetime(belgium['Year']).dt.year
canada['Year'] = pd.to_datetime(canada['Year']).dt.year
denmark['Year'] = pd.to_datetime(denmark['Year']).dt.year
finland['Year'] = pd.to_datetime(finland['Year']).dt.year
france['Year'] = pd.to_datetime(france['Year']).dt.year
germany['Year'] = pd.to_datetime(germany['Year']).dt.year
greece['Year'] = pd.to_datetime(greece['Year']).dt.year
hungary['Year'] = pd.to_datetime(hungary['Year']).dt.year
iceland['Year'] = pd.to_datetime(iceland['Year']).dt.year
ireland['Year'] = pd.to_datetime(ireland['Year']).dt.year
italy['Year'] = pd.to_datetime(italy['Year']).dt.year
japan['Year'] = pd.to_datetime(japan['Year']).dt.year
south_korea['Year'] = pd.to_datetime(south_korea['Year']).dt.year
luxembourg['Year'] = pd.to_datetime(luxembourg['Year']).dt.year
mexico['Year'] = pd.to_datetime(mexico['Year']).dt.year
netherlands['Year'] = pd.to_datetime(netherlands['Year']).dt.year
new_zealand['Year'] = pd.to_datetime(new_zealand['Year']).dt.year
norway['Year'] = pd.to_datetime(norway['Year']).dt.year
poland['Year'] = pd.to_datetime(poland['Year']).dt.year
portugal['Year'] = pd.to_datetime(portugal['Year']).dt.year
# slovakia['Year'] = pd.to_datetime(slovakia['Year']).dt.year
spain['Year'] = pd.to_datetime(spain['Year']).dt.year
sweden['Year'] = pd.to_datetime(sweden['Year']).dt.year
switzerland['Year'] = pd.to_datetime(switzerland['Year']).dt.year
turkey['Year'] = pd.to_datetime(turkey['Year']).dt.year
united_kingdom['Year'] = pd.to_datetime(united_kingdom['Year']).dt.year
united_states['Year'] = pd.to_datetime(united_states['Year']).dt.year
russia['Year'] = pd.to_datetime(russia['Year']).dt.year
china['Year'] = pd.to_datetime(china['Year']).dt.year
india['Year'] = pd.to_datetime(india['Year']).dt.year
brazil['Year'] = pd.to_datetime(brazil['Year']).dt.year
chile['Year'] = pd.to_datetime(chile['Year']).dt.year
colombia['Year'] = pd.to_datetime(colombia['Year']).dt.year
estonia['Year'] = pd.to_datetime(estonia['Year']).dt.year
israel['Year'] = pd.to_datetime(israel['Year']).dt.year
# lithuania['Year'] = pd.to_datetime(lithuania['Year']).dt.year
slovenia['Year'] = pd.to_datetime(slovenia['Year']).dt.year
# malaysia['Year'] = pd.to_datetime(malaysia['Year']).dt.year
# thailand['Year'] = pd.to_datetime(thailand['Year']).dt.year
indonesia['Year'] = pd.to_datetime(indonesia['Year']).dt.year
south_africa['Year'] = pd.to_datetime(south_africa['Year']).dt.year
latvia['Year'] = pd.to_datetime(latvia['Year']).dt.year
argentina['Year'] = pd.to_datetime(argentina['Year']).dt.year
bulgaria['Year'] = pd.to_datetime(bulgaria['Year']).dt.year
costa_rica['Year'] = pd.to_datetime(costa_rica['Year']).dt.year
croatia['Year'] = pd.to_datetime(croatia['Year']).dt.year
cyprus['Year'] = pd.to_datetime(cyprus['Year']).dt.year
lithuania['Year'] = pd.to_datetime(lithuania['Year']).dt.year
malta['Year'] = pd.to_datetime(malta['Year']).dt.year
romania['Year'] = pd.to_datetime(romania['Year']).dt.year
saudi_arabia['Year'] = pd.to_datetime(saudi_arabia['Year']).dt.year
singapore['Year'] = pd.to_datetime(singapore['Year']).dt.year

# %%
# Change the year column to 
australia['Year'] = australia['Year'].astype(int)
austria['Year'] = austria['Year'].astype(int)
belgium['Year'] = belgium['Year'].astype(int)
canada['Year'] = canada['Year'].astype(int)
denmark['Year'] = denmark['Year'].astype(int)
finland['Year'] = finland['Year'].astype(int)
france['Year'] = france['Year'].astype(int)
germany['Year'] = germany['Year'].astype(int)

greece['Year'] = greece['Year'].astype(int)
hungary['Year'] = hungary['Year'].astype(int)
iceland['Year'] = iceland['Year'].astype(int)
ireland['Year'] = ireland['Year'].astype(int)
italy['Year'] = italy['Year'].astype(int)
japan['Year'] = japan['Year'].astype(int)
south_korea['Year'] = south_korea['Year'].astype(int)
luxembourg['Year'] = luxembourg['Year'].astype(int)
mexico['Year'] = mexico['Year'].astype(int)
netherlands['Year'] = netherlands['Year'].astype(int)
new_zealand['Year'] = new_zealand['Year'].astype(int)
norway['Year'] = norway['Year'].astype(int)
poland['Year'] = poland['Year'].astype(int)
portugal['Year'] = portugal['Year'].astype(int)
# slovakia['Year'] = slovakia['Year'].astype(int)
spain['Year'] = spain['Year'].astype(int)
sweden['Year'] = sweden['Year'].astype(int)
switzerland['Year'] = switzerland['Year'].astype(int)
turkey['Year'] = turkey['Year'].astype(int)
united_kingdom['Year'] = united_kingdom['Year'].astype(int)
united_states['Year'] = united_states['Year'].astype(int)
russia['Year'] = russia['Year'].astype(int)
china['Year'] = china['Year'].astype(int)
india['Year'] = india['Year'].astype(int)
brazil['Year'] = brazil['Year'].astype(int)
chile['Year'] = chile['Year'].astype(int)
colombia['Year'] = colombia['Year'].astype(int)
estonia['Year'] = estonia['Year'].astype(int)
israel['Year'] = israel['Year'].astype(int)
# lithuania['Year'] = lithuania['Year'].astype(int)
slovenia['Year'] = slovenia['Year'].astype(int)
# malaysia['Year'] = malaysia['Year'].astype(int)
# thailand['Year'] = thailand['Year'].astype(int)
indonesia['Year'] = indonesia['Year'].astype(int)
south_africa['Year'] = south_africa['Year'].astype(int)
latvia['Year'] = latvia['Year'].astype(int)
argentina['Year'] = argentina['Year'].astype(int)
bulgaria['Year'] = bulgaria['Year'].astype(int)
costa_rica['Year'] = costa_rica['Year'].astype(int)
croatia['Year'] = croatia['Year'].astype(int)
cyprus['Year'] = cyprus['Year'].astype(int)
lithuania['Year'] = lithuania['Year'].astype(int)
malta['Year'] = malta['Year'].astype(int)
romania['Year'] = romania['Year'].astype(int)
saudi_arabia['Year'] = saudi_arabia['Year'].astype(int)
singapore['Year'] = singapore['Year'].astype(int)

# %%
# Rename  ' Life Expectancy from Birth (Years)' column to LifeExp Value column for each country dataframe
australia = australia.rename(columns={" Life Expectancy from Birth (Years)": "LifeExp Value"})
austria = austria.rename(columns={" Life Expectancy from Birth (Years)": "LifeExp Value"})
belgium = belgium.rename(columns={" Life Expectancy from Birth (Years)": "LifeExp Value"})
canada = canada.rename(columns={" Life Expectancy from Birth (Years)": "LifeExp Value"})
denmark = denmark.rename(columns={" Life Expectancy from Birth (Years)": "LifeExp Value"})
finland = finland.rename(columns={" Life Expectancy from Birth (Years)": "LifeExp Value"})
france = france.rename(columns={" Life Expectancy from Birth (Years)": "LifeExp Value"})
germany = germany.rename(columns={" Life Expectancy from Birth (Years)": "LifeExp Value"})
greece = greece.rename(columns={" Life Expectancy from Birth (Years)": "LifeExp Value"})
hungary = hungary.rename(columns={" Life Expectancy from Birth (Years)": "LifeExp Value"})
iceland = iceland.rename(columns={" Life Expectancy from Birth (Years)": "LifeExp Value"})
ireland = ireland.rename(columns={" Life Expectancy from Birth (Years)": "LifeExp Value"})
italy = italy.rename(columns={" Life Expectancy from Birth (Years)": "LifeExp Value"})
japan = japan.rename(columns={" Life Expectancy from Birth (Years)": "LifeExp Value"})
south_korea = south_korea.rename(columns={" Life Expectancy from Birth (Years)": "LifeExp Value"})
luxembourg = luxembourg.rename(columns={" Life Expectancy from Birth (Years)": "LifeExp Value"})
mexico = mexico.rename(columns={" Life Expectancy from Birth (Years)": "LifeExp Value"})
netherlands = netherlands.rename(columns={" Life Expectancy from Birth (Years)": "LifeExp Value"})
new_zealand = new_zealand.rename(columns={" Life Expectancy from Birth (Years)": "LifeExp Value"})
norway = norway.rename(columns={" Life Expectancy from Birth (Years)": "LifeExp Value"})
poland = poland.rename(columns={" Life Expectancy from Birth (Years)": "LifeExp Value"})
portugal = portugal.rename(columns={" Life Expectancy from Birth (Years)": "LifeExp Value"})
# slovakia = slovakia.rename(columns={" Life Expectancy from Birth (Years)": "LifeExp Value"})
spain = spain.rename(columns={" Life Expectancy from Birth (Years)": "LifeExp Value"})
sweden = sweden.rename(columns={" Life Expectancy from Birth (Years)": "LifeExp Value"})
switzerland = switzerland.rename(columns={" Life Expectancy from Birth (Years)": "LifeExp Value"})
turkey = turkey.rename(columns={" Life Expectancy from Birth (Years)": "LifeExp Value"})
united_kingdom = united_kingdom.rename(columns={" Life Expectancy from Birth (Years)": "LifeExp Value"})
united_states = united_states.rename(columns={" Life Expectancy from Birth (Years)": "LifeExp Value"})
russia = russia.rename(columns={" Life Expectancy from Birth (Years)": "LifeExp Value"})
china = china.rename(columns={" Life Expectancy from Birth (Years)": "LifeExp Value"})
india = india.rename(columns={" Life Expectancy from Birth (Years)": "LifeExp Value"})
brazil = brazil.rename(columns={" Life Expectancy from Birth (Years)": "LifeExp Value"})
chile = chile.rename(columns={" Life Expectancy from Birth (Years)": "LifeExp Value"})
colombia = colombia.rename(columns={" Life Expectancy from Birth (Years)": "LifeExp Value"})
estonia = estonia.rename(columns={" Life Expectancy from Birth (Years)": "LifeExp Value"})
israel = israel.rename(columns={" Life Expectancy from Birth (Years)": "LifeExp Value"})
# lithuania = lithuania.rename(columns={" Life Expectancy from Birth (Years)": "LifeExp Value"})
slovenia = slovenia.rename(columns={" Life Expectancy from Birth (Years)": "LifeExp Value"})
# malaysia = malaysia.rename(columns={" Life Expectancy from Birth (Years)": "LifeExp Value"})
# thailand = thailand.rename(columns={" Life Expectancy from Birth (Years)": "LifeExp Value"})
indonesia = indonesia.rename(columns={" Life Expectancy from Birth (Years)": "LifeExp Value"})
south_africa = south_africa.rename(columns={" Life Expectancy from Birth (Years)": "LifeExp Value"})
latvia = latvia.rename(columns={" Life Expectancy from Birth (Years)": "LifeExp Value"})
argentina = argentina.rename(columns={" Life Expectancy from Birth (Years)": "LifeExp Value"})
bulgaria = bulgaria.rename(columns={" Life Expectancy from Birth (Years)": "LifeExp Value"})
costa_rica = costa_rica.rename(columns={" Life Expectancy from Birth (Years)": "LifeExp Value"})
croatia = croatia.rename(columns={" Life Expectancy from Birth (Years)": "LifeExp Value"})
cyprus = cyprus.rename(columns={" Life Expectancy from Birth (Years)": "LifeExp Value"})
lithuania = lithuania.rename(columns={" Life Expectancy from Birth (Years)": "LifeExp Value"})
malta = malta.rename(columns={" Life Expectancy from Birth (Years)": "LifeExp Value"})
romania = romania.rename(columns={" Life Expectancy from Birth (Years)": "LifeExp Value"})
saudi_arabia = saudi_arabia.rename(columns={" Life Expectancy from Birth (Years)": "LifeExp Value"})
singapore = singapore.rename(columns={" Life Expectancy from Birth (Years)": "LifeExp Value"})

# %%
# Show unique values in the country column
merge6['LOCATION'].unique()
# Out:
# array(['Australia', 'Austria', 'Belgium', 'Canada', 'Czechia', 'Denmark',
#        'Finland', 'France', 'Germany', 'Greece', 'Hungary', 'Iceland',
#        'Ireland', 'Italy', 'Japan', 'Republic of Korea', 'Luxembourg',
#        'Mexico', 'Netherlands', 'New Zealand', 'Norway', 'Poland',
#        'Portugal', 'Slovakia', 'Spain', 'Sweden', 'Switzerland',
#        'Türkiye', 'United Kingdom', 'United States of America', 'Brazil',
#        'Chile', 'Colombia', 'Estonia', 'Israel', 'Russian Federation',
#        'Slovenia', 'China', 'India', 'Indonesia', 'South Africa', 'OECD',
#        'Latvia', 'Argentina', 'Bulgaria', 'Costa Rica', 'Croatia',
#        'Cyprus', 'Lithuania', 'Malta', 'Romania', 'Saudi Arabia',
#        'Singapore', 'WORLD', 'G20 Countrues', 'EUROPE'], dtype=object)

# %%
# Replace the empty values with in LifeExp Value column in merge6 with the values from each country's dataframe.
# Make sure it maches to the Year column.
# Do it for every country

merge6.loc[merge6['LOCATION'] == 'Australia', 'LifeExp Value'] = australia['LifeExp Value']
merge6.loc[merge6['LOCATION'] == 'Austria', 'LifeExp Value'] = austria['LifeExp Value']
merge6.loc[merge6['LOCATION'] == 'Belgium', 'LifeExp Value'] = belgium['LifeExp Value']
merge6.loc[merge6['LOCATION'] == 'Canada', 'LifeExp Value'] = canada['LifeExp Value']
merge6.loc[merge6['LOCATION'] == 'Denmark', 'LifeExp Value'] = denmark['LifeExp Value']
merge6.loc[merge6['LOCATION'] == 'Finland', 'LifeExp Value'] = finland['LifeExp Value']
merge6.loc[merge6['LOCATION'] == 'France', 'LifeExp Value'] = france['LifeExp Value']
merge6.loc[merge6['LOCATION'] == 'Germany', 'LifeExp Value'] = germany['LifeExp Value']
merge6.loc[merge6['LOCATION'] == 'Greece', 'LifeExp Value'] = greece['LifeExp Value']
merge6.loc[merge6['LOCATION'] == 'Hungary', 'LifeExp Value'] = hungary['LifeExp Value']
merge6.loc[merge6['LOCATION'] == 'Iceland', 'LifeExp Value'] = iceland['LifeExp Value']
merge6.loc[merge6['LOCATION'] == 'Ireland', 'LifeExp Value'] = ireland['LifeExp Value']
merge6.loc[merge6['LOCATION'] == 'Italy', 'LifeExp Value'] = italy['LifeExp Value']
merge6.loc[merge6['LOCATION'] == 'Japan', 'LifeExp Value'] = japan['LifeExp Value']
merge6.loc[merge6['LOCATION'] == 'Republic of Korea', 'LifeExp Value'] = south_korea['LifeExp Value']
merge6.loc[merge6['LOCATION'] == 'Luxembourg', 'LifeExp Value'] = luxembourg['LifeExp Value']
merge6.loc[merge6['LOCATION'] == 'Mexico', 'LifeExp Value'] = mexico['LifeExp Value']
merge6.loc[merge6['LOCATION'] == 'Netherlands', 'LifeExp Value'] = netherlands['LifeExp Value']
merge6.loc[merge6['LOCATION'] == 'New Zealand', 'LifeExp Value'] = new_zealand['LifeExp Value']
merge6.loc[merge6['LOCATION'] == 'Norway', 'LifeExp Value'] = norway['LifeExp Value']
merge6.loc[merge6['LOCATION'] == 'Poland', 'LifeExp Value'] = poland['LifeExp Value']
merge6.loc[merge6['LOCATION'] == 'Portugal', 'LifeExp Value'] = portugal['LifeExp Value']
# merge6.loc[merge6['LOCATION'] == 'Slovak Republic', 'LifeExp Value'] = slovakia['LifeExp Value']
merge6.loc[merge6['LOCATION'] == 'Spain', 'LifeExp Value'] = spain['LifeExp Value']
merge6.loc[merge6['LOCATION'] == 'Sweden', 'LifeExp Value'] = sweden['LifeExp Value']
merge6.loc[merge6['LOCATION'] == 'Switzerland', 'LifeExp Value'] = switzerland['LifeExp Value']
merge6.loc[merge6['LOCATION'] == 'Türkiye', 'LifeExp Value'] = turkey['LifeExp Value']
merge6.loc[merge6['LOCATION'] == 'United Kingdom', 'LifeExp Value'] = united_kingdom['LifeExp Value']
merge6.loc[merge6['LOCATION'] == 'United States of America', 'LifeExp Value'] = united_states['LifeExp Value']
merge6.loc[merge6['LOCATION'] == 'Russian Federation', 'LifeExp Value'] = russia['LifeExp Value']
merge6.loc[merge6['LOCATION'] == 'China', 'LifeExp Value'] = china['LifeExp Value']
merge6.loc[merge6['LOCATION'] == 'India', 'LifeExp Value'] = india['LifeExp Value']
merge6.loc[merge6['LOCATION'] == 'Brazil', 'LifeExp Value'] = brazil['LifeExp Value']
merge6.loc[merge6['LOCATION'] == 'Chile', 'LifeExp Value'] = chile['LifeExp Value']
merge6.loc[merge6['LOCATION'] == 'Colombia', 'LifeExp Value'] = colombia['LifeExp Value']
merge6.loc[merge6['LOCATION'] == 'Estonia', 'LifeExp Value'] = estonia['LifeExp Value']
merge6.loc[merge6['LOCATION'] == 'Israel', 'LifeExp Value'] = israel['LifeExp Value']
# merge6.loc[merge6['LOCATION'] == 'Lithuania', 'LifeExp Value'] = lithuania['LifeExp Value']
merge6.loc[merge6['LOCATION'] == 'Slovenia', 'LifeExp Value'] = slovenia['LifeExp Value']
# merge6.loc[merge6['LOCATION'] == 'Malaysia', 'LifeExp Value'] = malaysia['LifeExp Value']
# merge6.loc[merge6['LOCATION'] == 'Thailand', 'LifeExp Value'] = thailand['LifeExp Value']
merge6.loc[merge6['LOCATION'] == 'Indonesia', 'LifeExp Value'] = indonesia['LifeExp Value']
merge6.loc[merge6['LOCATION'] == 'South Africa', 'LifeExp Value'] = south_africa['LifeExp Value']
merge6.loc[merge6['LOCATION'] == 'Latvia', 'LifeExp Value'] = latvia['LifeExp Value']
merge6.loc[merge6['LOCATION'] == 'Argentina', 'LifeExp Value'] = argentina['LifeExp Value']
merge6.loc[merge6['LOCATION'] == 'Bulgaria', 'LifeExp Value'] = bulgaria['LifeExp Value']
merge6.loc[merge6['LOCATION'] == 'Costa Rica', 'LifeExp Value'] = costa_rica['LifeExp Value']
merge6.loc[merge6['LOCATION'] == 'Croatia', 'LifeExp Value'] = croatia['LifeExp Value']
merge6.loc[merge6['LOCATION'] == 'Cyprus', 'LifeExp Value'] = cyprus['LifeExp Value']
merge6.loc[merge6['LOCATION'] == 'Lithuania', 'LifeExp Value'] = lithuania['LifeExp Value']
merge6.loc[merge6['LOCATION'] == 'Malta', 'LifeExp Value'] = malta['LifeExp Value']
merge6.loc[merge6['LOCATION'] == 'Romania', 'LifeExp Value'] = romania['LifeExp Value']
merge6.loc[merge6['LOCATION'] == 'Saudi Arabia', 'LifeExp Value'] = saudi_arabia['LifeExp Value']
merge6.loc[merge6['LOCATION'] == 'Singapore', 'LifeExp Value'] = singapore['LifeExp Value']

# %%
# Add the LifeExp Value column to the merge6 dataframe for each country
merge6['LifeExp Value'] = merge6['LifeExp Value']

# %%
merge6.to_csv('merge.csv')

# %%
# Show the unique values in the LOCATION column and its LifeExp Value values
merge6.loc[merge6['LOCATION'] == 'Singapore']
# Out:
#        LOCATION  Year  Education Value  GDP Value  LifeExp Value  \
# 3796  Singapore  1950              NaN        NaN            NaN
# 3797  Singapore  1951              NaN        NaN            NaN
# 3798  Singapore  1952              NaN        NaN            NaN
# 3799  Singapore  1953              NaN        NaN            NaN
# 3800  Singapore  1954              NaN        NaN            NaN
# ...         ...   ...              ...        ...            ...
# 3864  Singapore  2018              NaN        NaN            NaN
# 3865  Singapore  2019              NaN        NaN            NaN
# 3866  Singapore  2020              NaN        NaN            NaN
# 3867  Singapore  2021              NaN        NaN            NaN
# 3868  Singapore  2022              NaN        NaN            NaN
#
#       Population Value  PopulationDensityAsOf1July(PersonsPerSquareKm)  \
# 3796         1022095.0                                          1473.9
# ...

# %%
merge6.head(50)
# Out:
#      LOCATION  Year  Education Value     GDP Value  LifeExp Value  \
# 0   Australia  1950              NaN           NaN         68.766
# 1   Australia  1951              NaN           NaN         68.974
# 2   Australia  1952              NaN           NaN         69.182
# 3   Australia  1953              NaN           NaN         69.390
# 4   Australia  1954              NaN           NaN         69.598
# 5   Australia  1955              NaN           NaN         69.806
# 6   Australia  1956              NaN           NaN         70.014
# 7   Australia  1957              NaN           NaN         70.222
# 8   Australia  1958              NaN           NaN         70.430
# 9   Australia  1959              NaN           NaN         70.520
# 10  Australia  1960              NaN   2412.627589         70.610
# 11  Australia  1961              NaN   2383.188902         70.700
# 12  Australia  1962              NaN   2577.332834         70.790
# ...

# %%
merge1 = pd.merge(merge6.loc[merge6['LOCATION'] == 'Australia'], australia, on=['Year', "LifeExp Value"])
merge1.head()
# Out:
# Empty DataFrame
# Columns: [LOCATION, Year, Education Value, GDP Value, LifeExp Value, Population Value, PopulationDensityAsOf1July(PersonsPerSquareKm), TotalFertilityRate(LiveBirthsPerWoman), LifeExpectancyAtBirthBothSexes(years), InfantMortalityRate(InfantDeathsPer1000LiveBirths),  Annual % Change]
# Index: []

# %%
# Find rows that is LOCATION = Australia
merge6.loc[merge6['LOCATION'] == 'Australia']
# Out:
#      LOCATION  Year  Education Value    GDP Value  LifeExp Value  \
# 0   Australia  1950              NaN          NaN            NaN
# 1   Australia  1951              NaN          NaN            NaN
# 2   Australia  1952              NaN          NaN            NaN
# 3   Australia  1953              NaN          NaN            NaN
# 4   Australia  1954              NaN          NaN            NaN
# ..        ...   ...              ...          ...            ...
# 68  Australia  2018        51.393173  53025.38690           82.7
# 69  Australia  2019        52.478458  52785.25056           82.9
# 70  Australia  2020        54.614105  55772.74108           83.2
# 71  Australia  2021        54.307404  62095.40433           83.3
# 72  Australia  2022        55.932438  70011.35139            NaN
#
#     Population Value  PopulationDensityAsOf1July(PersonsPerSquareKm)  \
# 0          8178700.0                                             1.1
# ...

# %%
# merge each country dataframe onto the merge6 dataframe on the year column and do it for every country.
# Make sure
